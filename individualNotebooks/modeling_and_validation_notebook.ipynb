# %% [markdown]
# ### Importing python libraries required for the analysis.
#
# **Note:** To ensure that all packages are loaded successfully, please ensure that you are in the right python environment. For more reference, refer the (how-to-set-environment)[link to the file] to ensure you have the correct working environment to run this notebook.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as stats
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

#import fiona
#import geopandas as gpd
#from shapely.geometry import Point
#import pyproj
#import folium

from patsy import dmatrices
from statsmodels.stats.outliers_influence import variance_inflation_factor
import statsmodels.api as sm
from statsmodels.formula.api import ols


from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.dummy import DummyRegressor
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OrdinalEncoder, OneHotEncoder, PolynomialFeatures
from sklearn.compose import ColumnTransformer
from sklearn.feature_selection import RFE
from pandas.api.types import is_numeric_dtype

# %% [markdown]
# ### Define Helper Functions for analysis

# %%
def dataframe_info(df):
    '''
    Takes Pandas dataframe (df). Prints number of rows, number of columns, and three sample rows.
    Returns list of numerical columns and list of non-numerical columns.
    '''
    numeric_cols = df.select_dtypes(include=np.number).columns.tolist()
    object_cols  = df.select_dtypes(exclude=np.number).columns.tolist()

    nrows, ncol = df.shape
    nmid = nrows // 2
    
    print(f"Dimensions: {nrows} rows and {ncol} columns")
    print(f"Numeric columns: {len(numeric_cols)}")
    print(f"Object columns: {len(object_cols)}")

    display(df.iloc[[0,nmid,nrows-1]]) # show three rows: first, mid, and last

    return numeric_cols, object_cols

# %%
def cleaned_column_names(column_list):
    '''
    Takes list of column names (e.g. from df.columns). 
    Returns list of cleaned column names that can be assigned to DataFrame.
    Usage: df.columns = cleaned_column_names(df.columns)
    '''
    return [name.strip().lower().replace(' ','').replace('-', '_') for name in column_list]

# %% [markdown]
# ## Data Exploration & Preparation

# %% [markdown]
# ### Load King County Housing data

# %%
housing_df = pd.read_csv('../data/housing_gdf_complete.csv')
housing_df.columns = cleaned_column_names(housing_df.columns)

# %%
num, obj = dataframe_info(housing_df)
# Out:
# Dimensions: 21596 rows and 28 columns
# Numeric columns: 17
# Object columns: 11
#        unnamed:0          id        date      price  bedrooms  bathrooms  \
# 0              0  8856004730   9/17/2014   199950.0         2       2.75
# 10798      10798  7237500590  11/17/2014  1320000.0         4       5.25
# 21595      21595  9808100150    4/2/2015  3350000.0         5       3.75
#
#        sqft_living  sqft_lot  floors waterfront  ...      lat     long  \
# 0             1590     20917     1.5         NO  ...  47.2786 -122.250
# 10798         6110     10369     2.0         NO  ...  47.5285 -122.135
# 21595         5350     15360     1.0         NO  ...  47.6480 -122.218
#
#       sqft_living15  sqft_lot15                coord  \
# 0              1310        6000   (-122.25, 47.2786)
# 10798          4190       10762  (-122.135, 47.5285)
# 21595          3740       15940   (-122.218, 47.648)
#
#                                            geometry          city  \
# 0      POINT (392815.9311460542 31962.040946318088)        Algona
# 10798  POINT (401985.90108066204 59588.48465827319)     Newcastle
# 21595  POINT (395975.83394082234 72981.52286293103)  Yarrow Point
#
#        dist_seattle  neighborhood  in_seattle
# 0      38586.298196           NaN       False
# 10798  19145.331588           NaN       False
# 21595  10564.303190           NaN       False
#
# [3 rows x 28 columns]

# %%
# convert dist_seattle from meters to miles
housing_df['dist_seattle'] = housing_df['dist_seattle'] / 1609.34

# %% [markdown]
# ## Data Mapping

# %%
housing_df[num].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21596 entries, 0 to 21595
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   unnamed:0      21596 non-null  int64
#  1   id             21596 non-null  int64
#  2   price          21596 non-null  float64
#  3   bedrooms       21596 non-null  int64
#  4   bathrooms      21596 non-null  float64
#  5   sqft_living    21596 non-null  int64
#  6   sqft_lot       21596 non-null  int64
#  7   floors         21596 non-null  float64
#  8   sqft_above     21596 non-null  int64
#  9   yr_built       21596 non-null  int64
#  10  yr_renovated   17754 non-null  float64
#  11  zipcode        21596 non-null  int64
#  12  lat            21596 non-null  float64
#  13  long           21596 non-null  float64
#  14  sqft_living15  21596 non-null  int64
#  15  sqft_lot15     21596 non-null  int64
#  16  dist_seattle   21596 non-null  float64
# dtypes: float64(7), int64(10)
# memory usage: 2.8 MB

# %%
housing_df[obj].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21596 entries, 0 to 21595
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           21596 non-null  object
#  1   waterfront     19221 non-null  object
#  2   view           21533 non-null  object
#  3   condition      21596 non-null  object
#  4   grade          21596 non-null  object
#  5   sqft_basement  21596 non-null  object
#  6   coord          21596 non-null  object
#  7   geometry       21596 non-null  object
#  8   city           21596 non-null  object
#  9   neighborhood   6735 non-null   object
#  10  in_seattle     21596 non-null  bool
# dtypes: bool(1), object(10)
# memory usage: 1.7+ MB

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Basement

# %%
# sqft_basement should equal difference between sqft_living and sqft_above
sqft_basement_computed = housing_df['sqft_living'] - housing_df['sqft_above']

housing_df['has_basement'] = (sqft_basement_computed > 0).astype(int)

# %% [markdown]
# ### Yr renovated

# %%
housing_df['sold_dt'] = pd.to_datetime(housing_df['date'])
housing_df['sold_year'] = pd.DatetimeIndex(housing_df['sold_dt']).year
housing_df['sold_month'] = pd.DatetimeIndex(housing_df['sold_dt']).month

# %%
housing_df['yr_renovated_missing'] = (housing_df['yr_renovated'].isna()).astype(int)
housing_df['yr_renovated'].fillna(0, inplace=True)

housing_df['renovated'] = ((housing_df['sold_year'] - housing_df['yr_renovated']) <= 5).astype(int)

# %% [markdown]
# ### Age of the house

# %%
housing_df['house_age'] = housing_df['sold_year'] - housing_df['yr_built']
housing_df['house_age'].describe()
# Out:
# count    21596.000000
# mean        43.323810
# std         29.377864
# min         -1.000000
# 25%         18.000000
# 50%         40.000000
# 75%         63.000000
# max        115.000000
# Name: house_age, dtype: float64

# %% [markdown]
# ### View

# %%
housing_df['view_missing'] = (housing_df['view'].isna()).astype(int)

# %%
housing_df['view'].fillna('NONE', inplace=True)

# %% [markdown]
# ### Waterfront

# %%
housing_df['waterfront_missing'] = (housing_df['waterfront'].isna()).astype(int)
housing_df['waterfront'].fillna('NO', inplace=True)

# %% [markdown]
# ### Duplicate records (house resold)

# %%
print(f"Number of rows:\t\t{len(housing_df['id'])}")
print(f"Number unique:\t\t{len(housing_df['id'].unique())}")
print(f"Number duplicates:\t{sum(housing_df['id'].duplicated() == True)}")
# Out:
# Number of rows:		21596
# Number unique:		21419
# Number duplicates:	177

# %%
housing_df = housing_df.sort_values(by=['sold_year', 'sold_month'])
housing_df['resold'] = housing_df.id.duplicated().astype(int)

# %% [markdown]
# ### Fill NaNs in neighborhood column

# %%
housing_df['neighborhood'] = housing_df['neighborhood'].fillna('NA')

# %% [markdown]
# ### Ratio between bedrooms and bathrooms

# %%
housing_df['br_bth'] = housing_df.bedrooms / housing_df.bathrooms

# %%
num,obj = dataframe_info(housing_df)
# Out:
# Dimensions: 21596 rows and 39 columns
# Numeric columns: 27
# Object columns: 12
#        unnamed:0          id       date      price  bedrooms  bathrooms  \
# 1              1  3356406510  5/30/2014   196440.0         3        2.0
# 10749      10749  1023089197  10/7/2014   390000.0         3        2.0
# 21594      21594  1925059254   5/7/2015  3000000.0         5        4.0
#
#        sqft_living  sqft_lot  floors waterfront  ...    sold_dt sold_year  \
# 1             1560      7352     1.0         NO  ... 2014-05-30      2014
# 10749         1930     12443     1.0         NO  ... 2014-10-07      2014
# 21594         6670     16481     2.0         NO  ... 2015-05-07      2015
#
#       sold_month  yr_renovated_missing renovated  house_age  view_missing  \
# 1              5                     0         0         22             0
# 10749         10                     0         0         45             0
# 21594          5                     1         0          8             0
#
#        waterfront_missing  resold  br_bth
# 1                       0       0    1.50
# 10749                   0       0    1.50
# 21594                   0       0    1.25
#
# [3 rows x 39 columns]

# %%
housing_df[num].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21596 entries, 1 to 21594
# Data columns (total 27 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   unnamed:0             21596 non-null  int64
#  1   id                    21596 non-null  int64
#  2   price                 21596 non-null  float64
#  3   bedrooms              21596 non-null  int64
#  4   bathrooms             21596 non-null  float64
#  5   sqft_living           21596 non-null  int64
#  6   sqft_lot              21596 non-null  int64
#  7   floors                21596 non-null  float64
#  8   sqft_above            21596 non-null  int64
#  9   yr_built              21596 non-null  int64
#  10  yr_renovated          21596 non-null  float64
#  11  zipcode               21596 non-null  int64
#  12  lat                   21596 non-null  float64
#  13  long                  21596 non-null  float64
#  14  sqft_living15         21596 non-null  int64
#  15  sqft_lot15            21596 non-null  int64
#  16  dist_seattle          21596 non-null  float64
#  17  has_basement          21596 non-null  int64
#  18  sold_year             21596 non-null  int64
#  19  sold_month            21596 non-null  int64
#  20  yr_renovated_missing  21596 non-null  int64
#  21  renovated             21596 non-null  int64
#  22  house_age             21596 non-null  int64
#  23  view_missing          21596 non-null  int64
#  24  waterfront_missing    21596 non-null  int64
#  25  resold                21596 non-null  int64
#  26  br_bth                21596 non-null  float64
# dtypes: float64(8), int64(19)
# memory usage: 4.6 MB

# %%
housing_df[obj].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21596 entries, 1 to 21594
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           21596 non-null  object
#  1   waterfront     21596 non-null  object
#  2   view           21596 non-null  object
#  3   condition      21596 non-null  object
#  4   grade          21596 non-null  object
#  5   sqft_basement  21596 non-null  object
#  6   coord          21596 non-null  object
#  7   geometry       21596 non-null  object
#  8   city           21596 non-null  object
#  9   neighborhood   21596 non-null  object
#  10  in_seattle     21596 non-null  bool
#  11  sold_dt        21596 non-null  datetime64[ns]
# dtypes: bool(1), datetime64[ns](1), object(10)
# memory usage: 2.0+ MB

# %% [markdown]
# ### In seattle

# %%
housing_df['in_seattle'] = housing_df['in_seattle'].astype(int)

# %%
filt = (housing_df['in_seattle']==1)
housing_df[filt].describe()
# Out:
#          unnamed:0            id         price     bedrooms    bathrooms  \
# count   6744.00000  6.744000e+03  6.744000e+03  6744.000000  6744.000000
# mean   15902.50000  4.679869e+09  5.916805e+05     3.137752     1.938760
# std     1946.96944  2.876990e+09  3.539196e+05     1.070067     0.804178
# min    12531.00000  3.600057e+06  9.000000e+04     1.000000     0.500000
# 25%    14216.75000  2.305775e+09  3.900000e+05     2.000000     1.000000
# 50%    15902.50000  4.077800e+09  5.100000e+05     3.000000     1.750000
# 75%    17588.25000  7.234602e+09  6.804000e+05     4.000000     2.500000
# max    19274.00000  9.842301e+09  7.700000e+06    33.000000     8.000000
#
#         sqft_living      sqft_lot       floors   sqft_above     yr_built  ...  \
# count   6744.000000   6744.000000  6744.000000  6744.000000  6744.000000  ...
# mean    1803.454923   5131.146056     1.543224  1436.195433  1953.305605  ...
# std      814.675424   3718.706992     0.617980   617.778976    35.096437  ...
# min      370.000000    520.000000     1.000000   370.000000  1900.000000  ...
# 25%     1240.000000   3240.000000     1.000000  1020.000000  1925.000000  ...
# 50%     1630.000000   4950.000000     1.500000  1290.000000  1947.000000  ...
# 75%     2200.000000   6337.500000     2.000000  1680.000000  1987.000000  ...
# max    12050.000000  91681.000000     3.500000  8570.000000  2015.000000  ...
#
#        has_basement    sold_year   sold_month  yr_renovated_missing  \
# count   6744.000000  6744.000000  6744.000000           6744.000000
# mean       0.561833  2014.314057     6.640273              0.183867
# std        0.496199     0.464174     3.093321              0.387405
# min        0.000000  2014.000000     1.000000              0.000000
# 25%        0.000000  2014.000000     4.000000              0.000000
# 50%        1.000000  2014.000000     6.000000              0.000000
# 75%        1.000000  2015.000000     9.000000              0.000000
# max        1.000000  2015.000000    12.000000              1.000000
#
#          renovated    house_age  view_missing  waterfront_missing  \
# count  6744.000000  6744.000000   6744.000000         6744.000000
# mean      0.014087    61.008452      0.002966            0.107651
# std       0.117857    35.095295      0.054381            0.309962
# min       0.000000    -1.000000      0.000000            0.000000
# 25%       0.000000    27.000000      0.000000            0.000000
# 50%       0.000000    67.000000      0.000000            0.000000
# 75%       0.000000    90.000000      0.000000            0.000000
# max       1.000000   115.000000      1.000000            1.000000
#
#             resold       br_bth
# count  6744.000000  6744.000000
# mean      0.007266     1.804936
# std       0.084935     0.755229
# min       0.000000     0.400000
# 25%       0.000000     1.230769
# 50%       0.000000     1.714286
# 75%       0.000000     2.000000
# max       1.000000    18.857143
#
# [8 rows x 28 columns]

# %%
filt = (housing_df['in_seattle']==0)
housing_df[filt].describe()
# Out:
#           unnamed:0            id         price      bedrooms     bathrooms  \
# count  14852.000000  1.485200e+04  1.485200e+04  14852.000000  14852.000000
# mean    8479.420280  4.535413e+09  5.169884e+05      3.480205      2.196304
# std     6130.898917  2.875668e+09  3.709863e+05      0.831310      0.738566
# min        0.000000  1.000102e+06  7.800000e+04      1.000000      0.500000
# 25%     3712.750000  2.025701e+09  2.972905e+05      3.000000      1.750000
# 50%     7425.500000  3.885806e+09  4.240000e+05      3.000000      2.250000
# 75%    11138.250000  7.323408e+09  6.200000e+05      4.000000      2.500000
# max    21595.000000  9.900000e+09  7.060000e+06     10.000000      8.000000
#
#         sqft_living      sqft_lot        floors    sqft_above      yr_built  \
# count  14852.000000  1.485200e+04  14852.000000  14852.000000  14852.000000
# mean    2206.107662  1.962632e+04      1.471822   1948.683275   1979.033464
# std      934.724279  4.921407e+04      0.498530    860.816074     22.109202
# min      380.000000  6.830000e+02      1.000000    380.000000   1900.000000
# 25%     1540.000000  7.116500e+03      1.000000   1300.000000   1963.000000
# 50%     2050.000000  9.000000e+03      1.000000   1730.000000   1980.000000
# 75%     2680.000000  1.312425e+04      2.000000   2430.000000   1998.000000
# max    13540.000000  1.651359e+06      3.000000   9410.000000   2015.000000
#
#        ...  has_basement     sold_year    sold_month  yr_renovated_missing  \
# count  ...  14852.000000  14852.000000  14852.000000          14852.000000
# mean   ...      0.316254   2014.327027      6.543563              0.175195
# std    ...      0.465029      0.469143      3.124413              0.380147
# min    ...      0.000000   2014.000000      1.000000              0.000000
# 25%    ...      0.000000   2014.000000      4.000000              0.000000
# 50%    ...      0.000000   2014.000000      6.000000              0.000000
# 75%    ...      1.000000   2015.000000      9.000000              0.000000
# max    ...      1.000000   2015.000000     12.000000              1.000000
#
#           renovated     house_age  view_missing  waterfront_missing  \
# count  14852.000000  14852.000000  14852.000000        14852.000000
# mean       0.004646     35.293563      0.002895            0.111029
# std        0.068004     22.118686      0.053731            0.314178
# min        0.000000     -1.000000      0.000000            0.000000
# 25%        0.000000     17.000000      0.000000            0.000000
# 50%        0.000000     35.000000      0.000000            0.000000
# 75%        0.000000     51.000000      0.000000            0.000000
# max        1.000000    115.000000      1.000000            1.000000
#
#              resold        br_bth
# count  14852.000000  14852.000000
# mean       0.008618      1.727804
# std        0.092437      0.616278
# min        0.000000      0.400000
# 25%        0.000000      1.333333
# 50%        0.000000      1.600000
# 75%        0.000000      2.000000
# max        1.000000      8.000000
#
# [8 rows x 28 columns]

# %% [markdown]
# ## Verify that columns are not collinear

# %% [markdown]
# ### Remove collinear numeric columns

# %% [markdown]
# Manually edited columns in `relevant_num_cols` to eliminate columns correlated > 0.7 with other columns

# %%
relevant_num_cols = [
    'bedrooms',
    'sqft_living',
    'sqft_lot',
    'floors',
    'dist_seattle',
    'has_basement',
    'yr_renovated_missing',
    'house_age',
    'view_missing',
    'waterfront_missing',
    'resold',
    'br_bth', 
    'renovated'
]

# %%
sns.heatmap(housing_df[relevant_num_cols].corr().abs(), vmin=.7, vmax=0.7);

# %% [markdown]
# ### Remove collinear categorical columns

# %% [markdown]
# Collinearity of categorical columns will need to be verified using VIF after running statsmodels. Collinear categorical columns can be removed here.

# %%
relevant_cat_col =  [
    'waterfront',
    'zipcode',
    'view',
    'condition',
    'grade',
    'city',
    'neighborhood'
  ]

# %% [markdown]
# ### Train test split

# %%
y = housing_df['price']
X = housing_df[relevant_num_cols+relevant_cat_col]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %% [markdown]
# ## One Hot Encoder

# %%
# Version of OHE in learn-env won't allow you to set drop flag and handle_unknown flag
#                        drop='if_binary',
encoder = OneHotEncoder(handle_unknown='ignore',
                        categories='auto') 

# Create ColumnTransformer to transform all relevant_cat_col columns with OHE encoder
ct = ColumnTransformer(transformers=[('ohe', encoder, relevant_cat_col)],
                       remainder='passthrough')

# Now that we have ct, fit it to the X_train, and apply that transformer to both X_train and X_test
ct.fit(X_train)
X_train_enc = ct.transform(X_train)
X_test_enc = ct.transform(X_test)

# %%
# Put encoder output back into DataFrame for X_train and X_test
X_train = pd.DataFrame(X_train_enc.todense(), columns= ct.get_feature_names(), index=X_train.index)
X_test = pd.DataFrame(X_test_enc.todense(), columns= ct.get_feature_names(), index=X_test.index)

# %% [markdown]
# Output of OHE ColumnTransformer is clunky and unwieldy. I'm creating a dict with a mapping to change the automated naming convention from the ct to something more human readable.

# %%
replace_dict = {
    'ohe__': '',
    'x0': 'waterfront',
    'x1': 'zip',
    'x2': 'view',
    'x3': 'condition',
    'x4': 'grade',
    'x5': 'city',
    'x6': 'neighborhood'
}

# %%
# Use cleaned_column_names to remove spaces
X_train.columns = cleaned_column_names(X_train.columns)

for key, value in replace_dict.items():
    X_train.columns = [ x.replace(key, value) for x in list(X_train.columns) ]

# %%
# Use cleaned_column_names to remove spaces
X_test.columns = cleaned_column_names(X_test.columns)

for key, value in replace_dict.items():
    X_test.columns = [ x.replace(key, value) for x in list(X_test.columns) ]

# %% [markdown]
# ## Get model metrics and validation using sklearn LinearRegression

# %%
def build_model(X_train, X_test, y_train, y_test):
    
    """
    Build a regression model
    
    """
    
    lr = LinearRegression()
    lr.fit(X_train,y_train)
    R2_train = lr.score(X_train,y_train)
    R2_test = lr.score(X_test,y_test)


    yhat_train = lr.predict(X_train)
    train_rmse = mean_squared_error(y_train, yhat_train, squared = False)

    yhat_test = lr.predict(X_test)
    test_rmse = mean_squared_error(y_test, yhat_test, squared = False)

    residuals_train = y_train - yhat_train
    residuals_test = y_test - yhat_test

    
    print(f'Train R2: {lr.score(X_train,y_train)}')
    print(f'Test R2: {lr.score(X_test,y_test)}')
    print(f'Train RMSE: {train_rmse}')
    print(f'Test RMSE: {test_rmse}')
    
    return yhat_train, residuals_train, yhat_test, residuals_test

# %%
model_base_cols = ['sqft_living', 'bedrooms']

Xbase_train = X_train[model_base_cols]
Xbase_test = X_test[model_base_cols]

#model_base_r2_train, model_base_r2_test, train_rmse, test_rmse = build_model(Xbase_train, Xbase_test, y_train, y_test)
base_yhat_train, base_residuals_train, base_yhat_test, base_residuals_test = build_model(Xbase_train, Xbase_test, y_train, y_test)
# Out:
# Train R2: 0.5077862105659562
# Test R2: 0.5046145987226243
# Train RMSE: 256307.81232314883
# Test RMSE: 261392.48743150264

# %%
sm.qqplot(base_residuals_train, line = 'r');

# %%
# histogram of residuals
ax = sns.histplot(base_residuals_train, stat='density', label='residuals')

# %%
plt.scatter(base_yhat_train, base_residuals_train)
plt.scatter(base_yhat_test, base_residuals_test, color='green');

plt.axhline(y=0, color = 'red', label = '0')
plt.xlabel('predictions')
plt.ylabel('residuals')
plt.legend();

# %%
# drop 'grade_7average' from OHE grade cols
model_1_cols = model_base_cols + \
    ['renovated', 'house_age', 'grade_10verygood', 'grade_11excellent', 'grade_12luxury', 'grade_13mansion', 
     'grade_3poor', 'grade_4low', 'grade_5fair', 'grade_6lowaverage', 'grade_8good', 'grade_9better']

X1_train = X_train[model_1_cols]
X1_test = X_test[model_1_cols]

model_1_yhat_train, model_1_residuals_train, model_1_yhat_test, model_1_residuals_test = build_model(X1_train, X1_test, y_train, y_test)
# Out:
# Train R2: 0.6324494751299137
# Test R2: 0.6452679034740165
# Train RMSE: 221484.57168204186
# Test RMSE: 221193.18511148528

# %%
sm.qqplot(model_1_residuals_train, line = 'r');

# %%
# histogram of residuals
ax = sns.histplot(model_1_residuals_train, stat='density', label='residuals')

# %%
plt.scatter(model_1_yhat_train, model_1_residuals_train)
plt.scatter(model_1_yhat_test, model_1_residuals_test, color='green');

plt.axhline(y=0, color = 'red', label = '0')
plt.xlabel('predictions')
plt.ylabel('residuals')
plt.legend();

# %%
model_2_cols = model_1_cols + \
    ['waterfront_yes', 'view_average', 'view_excellent', 'view_fair', 'view_good']

X2_train = X_train[model_2_cols]
X2_test = X_test[model_2_cols]

model_2_yhat_train, model_2_residuals_train, model_2_yhat_test, model_2_residuals_test = build_model(X2_train, X2_test, y_train, y_test)
# Out:
# Train R2: 0.6701286983460104
# Test R2: 0.6743158471010332
# Train RMSE: 209824.99560746498
# Test RMSE: 211943.3590738888

# %%
sm.qqplot(model_2_residuals_train, line = 'r');

# %%
ax = sns.histplot(model_2_residuals_train, stat='density', label='residuals');

# %%
plt.scatter(model_2_yhat_train, model_2_residuals_train)
plt.scatter(model_2_yhat_test, model_2_residuals_test, color='green');
plt.axhline(y=0, color = 'red', label = '0')
plt.xlabel('predictions')
plt.ylabel('residuals')
plt.legend();

# %%
model_3_cols = model_2_cols + \
    ['dist_seattle', 'neighborhood_ballard', 'neighborhood_beaconhill', 'neighborhood_capitolhill', 
     'neighborhood_cascade', 'neighborhood_centralarea', 'neighborhood_delridge', 
     'neighborhood_downtown', 'neighborhood_greaterduwamish', 'neighborhood_interbay', 
     'neighborhood_lakecity', 'neighborhood_magnolia', 'neighborhood_northcentral', 
     'neighborhood_northeast', 'neighborhood_northgate', 'neighborhood_northwest', 
     'neighborhood_queenanne', 'neighborhood_rainiervalley', 'neighborhood_sewardpark', 
     'neighborhood_universitydistrict', 'neighborhood_westseattle']

X3_train = X_train[model_3_cols]
X3_test = X_test[model_3_cols]

model_3_yhat_train, model_3_residuals_train, model_3_yhat_test, model_3_residuals_test = build_model(X3_train, X3_test, y_train, y_test)
# Out:
# Train R2: 0.7457573020375254
# Test R2: 0.7474142702554982
# Train RMSE: 184208.3022309081
# Test RMSE: 186649.10203977252

# %%
sm.qqplot(model_3_residuals_train, line = 'r');

# %%
ax = sns.histplot(model_3_residuals_train, stat='density', label='residuals');

# %%
plt.scatter(model_3_yhat_train, model_3_residuals_train)
plt.scatter(model_3_yhat_test, model_3_residuals_test, color='green');
plt.axhline(y=0, color = 'red', label = '0')
plt.xlabel('predictions')
plt.ylabel('residuals')
plt.legend();

# %%
model_4_cols = model_3_cols + \
    ['zip_98002','zip_98003','zip_98004','zip_98005','zip_98006','zip_98007','zip_98008','zip_98010',
     'zip_98011','zip_98014','zip_98019','zip_98022','zip_98023','zip_98024','zip_98027','zip_98028',
     'zip_98029','zip_98030','zip_98031','zip_98032','zip_98033','zip_98034','zip_98038','zip_98039',
     'zip_98040','zip_98042','zip_98045','zip_98052','zip_98053','zip_98055','zip_98056','zip_98058',
     'zip_98059','zip_98065','zip_98070','zip_98072','zip_98074','zip_98075','zip_98077','zip_98092',
     'zip_98102','zip_98103','zip_98105','zip_98106','zip_98107','zip_98108','zip_98109','zip_98112',
     'zip_98115','zip_98116','zip_98117','zip_98118','zip_98119','zip_98122','zip_98125','zip_98126',
     'zip_98133','zip_98136','zip_98144','zip_98146','zip_98148','zip_98155','zip_98166','zip_98168',
     'zip_98177','zip_98178','zip_98188','zip_98198','zip_98199']

X4_train = X_train[model_4_cols]
X4_test = X_test[model_4_cols]

model_4_yhat_train, model_4_residuals_train, model_4_yhat_test, model_4_residuals_test = build_model(X4_train, X4_test, y_train, y_test)
# Out:
# Train R2: 0.8338662057554318
# Test R2: 0.8292357587141828
# Train RMSE: 148906.6000219651
# Test RMSE: 153468.75359185

# %%
sm.qqplot(model_4_residuals_train, line = 'r');

# %%
ax = sns.histplot(model_4_residuals_train, stat='density', label='residuals');

# %%
plt.scatter(model_4_yhat_train, model_4_residuals_train)
plt.scatter(model_4_yhat_test, model_4_residuals_test, color='green');
plt.axhline(y=0, color = 'red', label = '0')
plt.xlabel('predictions')
plt.ylabel('residuals')
plt.legend();

# %% [markdown]
# ## Get human readable coefficients using statsmodels ols

# %%
# Code borrowed from lecture slides and put into function
def make_vif(formula, df):

    y, X = dmatrices(formula, data=df, return_type='dataframe')

    # make empty VIF dataframe
    vif = pd.DataFrame()
    vif["feature"] = X.columns
  
    # calculate VIF for each feature
    vif["VIF"] = [variance_inflation_factor(X.values, i) for i in range(len(X.columns))]

    return vif

# %%
train_df = pd.concat([X_train,y_train], axis=1)

# %%
model_base_formula = 'price ~ ' + ' + '.join(model_base_cols)

# %%
model_base_formula
# Out:
# 'price ~ sqft_living + bedrooms'

# %%
model_base_mod = ols(model_base_formula, train_df).fit()
model_base_mod_summary = model_base_mod.summary()
model_base_mod_summary
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.508
# Model:                            OLS   Adj. R-squared:                  0.508
# Method:                 Least Squares   F-statistic:                     7462.
# Date:                Thu, 31 Mar 2022   Prob (F-statistic):               0.00
# Time:                        22:24:35   Log-Likelihood:            -2.0073e+05
# No. Observations:               14469   AIC:                         4.015e+05
# Df Residuals:                   14466   BIC:                         4.015e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept    7.832e+04   8014.377      9.773      0.000    6.26e+04     9.4e+04
# sqft_living   312.3635      2.838    110.074      0.000     306.801     317.926
# bedrooms     -5.52e+04   2787.280    -19.805      0.000   -6.07e+04   -4.97e+04
# ==============================================================================
# Omnibus:                     9485.512   Durbin-Watson:                   1.997
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           299522.856
# Skew:                           2.682   Prob(JB):                         0.00
# Kurtosis:                      24.634   Cond. No.                     8.87e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.87e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
model_1_formula = 'price ~ ' + ' + '.join(model_1_cols)

# %%
model_1_mod = ols(model_1_formula, train_df).fit()
model_1_mod_summary = model_1_mod.summary()
model_1_mod_summary
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.632
# Model:                            OLS   Adj. R-squared:                  0.632
# Method:                 Least Squares   F-statistic:                     1777.
# Date:                Thu, 31 Mar 2022   Prob (F-statistic):               0.00
# Time:                        22:24:35   Log-Likelihood:            -1.9862e+05
# No. Observations:               14469   AIC:                         3.973e+05
# Df Residuals:                   14454   BIC:                         3.974e+05
# Df Model:                          14
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept          2.042e+04   8533.169      2.393      0.017    3690.738    3.71e+04
# sqft_living         178.5147      3.755     47.542      0.000     171.155     185.875
# bedrooms          -2.593e+04   2507.289    -10.340      0.000   -3.08e+04    -2.1e+04
# renovated          4.573e+04   2.09e+04      2.184      0.029    4678.761    8.68e+04
# house_age          3276.4880     72.203     45.379      0.000    3134.961    3418.015
# grade_10verygood    4.49e+05   1.06e+04     42.392      0.000    4.28e+05     4.7e+05
# grade_11excellent  7.191e+05   1.68e+04     42.848      0.000    6.86e+05    7.52e+05
# grade_12luxury     1.208e+06   3.09e+04     39.130      0.000    1.15e+06    1.27e+06
# grade_13mansion    2.211e+06   9.25e+04     23.896      0.000    2.03e+06    2.39e+06
# grade_3poor       -1.366e+05   2.22e+05     -0.616      0.538   -5.71e+05    2.98e+05
# grade_4low        -1.414e+05   4.98e+04     -2.837      0.005   -2.39e+05   -4.37e+04
# grade_5fair       -1.478e+05   1.84e+04     -8.038      0.000   -1.84e+05   -1.12e+05
# grade_6lowaverage  -9.86e+04   7005.736    -14.074      0.000   -1.12e+05   -8.49e+04
# grade_8good        1.125e+05   4944.007     22.759      0.000    1.03e+05    1.22e+05
# grade_9better      2.577e+05   7393.362     34.856      0.000    2.43e+05    2.72e+05
# ==============================================================================
# Omnibus:                     9803.526   Durbin-Watson:                   2.004
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           451722.191
# Skew:                           2.686   Prob(JB):                         0.00
# Kurtosis:                      29.841   Cond. No.                     2.74e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.74e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
display( make_vif(model_1_formula, train_df) )
# Out:
#               feature        VIF
# 0           Intercept  21.454666
# 1         sqft_living   3.494273
# 2            bedrooms   1.614960
# 3           renovated   1.009976
# 4           house_age   1.335793
# 5    grade_10verygood   1.692266
# 6   grade_11excellent   1.519918
# 7      grade_12luxury   1.218317
# 8     grade_13mansion   1.045282
# 9         grade_3poor   1.000838
# 10         grade_4low   1.010387
# 11        grade_5fair   1.048664
# 12  grade_6lowaverage   1.248529
# 13        grade_8good   1.462308
# 14      grade_9better   1.727540

# %%
model_2_formula = 'price ~ ' + ' + '.join(model_2_cols)

# %%
model_2_mod = ols(model_2_formula, train_df).fit()
model_2_mod_summary = model_2_mod.summary()
model_2_mod_summary
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.670
# Model:                            OLS   Adj. R-squared:                  0.670
# Method:                 Least Squares   F-statistic:                     1545.
# Date:                Thu, 31 Mar 2022   Prob (F-statistic):               0.00
# Time:                        22:24:35   Log-Likelihood:            -1.9783e+05
# No. Observations:               14469   AIC:                         3.957e+05
# Df Residuals:                   14449   BIC:                         3.959e+05
# Df Model:                          19
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept          3.838e+04   8118.057      4.728      0.000    2.25e+04    5.43e+04
# sqft_living         158.8125      3.610     43.994      0.000     151.737     165.888
# bedrooms          -1.746e+04   2386.704     -7.314      0.000   -2.21e+04   -1.28e+04
# renovated          4.902e+04   1.98e+04      2.470      0.014    1.01e+04    8.79e+04
# house_age          2913.9333     69.689     41.814      0.000    2777.335    3050.532
# grade_10verygood    4.28e+05   1.01e+04     42.508      0.000    4.08e+05    4.48e+05
# grade_11excellent  6.869e+05   1.59e+04     43.082      0.000    6.56e+05    7.18e+05
# grade_12luxury     1.167e+06   2.94e+04     39.758      0.000    1.11e+06    1.22e+06
# grade_13mansion     2.21e+06   8.78e+04     25.160      0.000    2.04e+06    2.38e+06
# grade_3poor       -1.183e+05    2.1e+05     -0.563      0.573    -5.3e+05    2.93e+05
# grade_4low        -1.409e+05   4.72e+04     -2.982      0.003   -2.33e+05   -4.83e+04
# grade_5fair       -1.554e+05   1.74e+04     -8.917      0.000    -1.9e+05   -1.21e+05
# grade_6lowaverage -9.778e+04   6639.612    -14.727      0.000   -1.11e+05   -8.48e+04
# grade_8good        1.067e+05   4699.997     22.701      0.000    9.75e+04    1.16e+05
# grade_9better      2.499e+05   7028.524     35.553      0.000    2.36e+05    2.64e+05
# waterfront_yes     6.109e+05   2.57e+04     23.810      0.000    5.61e+05    6.61e+05
# view_average       5.495e+04   8583.772      6.401      0.000    3.81e+04    7.18e+04
# view_excellent     2.422e+05   1.75e+04     13.859      0.000    2.08e+05    2.76e+05
# view_fair          1.297e+05   1.44e+04      8.973      0.000    1.01e+05    1.58e+05
# view_good          1.117e+05   1.16e+04      9.634      0.000    8.89e+04    1.34e+05
# ==============================================================================
# Omnibus:                     8175.984   Durbin-Watson:                   2.012
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           288459.861
# Skew:                           2.115   Prob(JB):                         0.00
# Kurtosis:                      24.461   Cond. No.                     2.74e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.74e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
display( make_vif(model_2_formula, train_df) )
# Out:
#               feature        VIF
# 0           Intercept  21.628557
# 1         sqft_living   3.597229
# 2            bedrooms   1.629943
# 3           renovated   1.010398
# 4           house_age   1.386032
# 5    grade_10verygood   1.703415
# 6   grade_11excellent   1.527942
# 7      grade_12luxury   1.225857
# 8     grade_13mansion   1.049505
# 9         grade_3poor   1.000848
# 10         grade_4low   1.010546
# 11        grade_5fair   1.049234
# 12  grade_6lowaverage   1.249104
# 13        grade_8good   1.471967
# 14      grade_9better   1.738981
# 15     waterfront_yes   1.394252
# 16       view_average   1.049672
# 17     view_excellent   1.433172
# 18          view_fair   1.016846
# 19          view_good   1.055142

# %%
model_3_formula = 'price ~ ' + ' + '.join(model_3_cols)

# %%
model_3_mod = ols(model_3_formula, train_df).fit()
model_3_mod_summary = model_3_mod.summary()
model_3_mod_summary
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.746
# Model:                            OLS   Adj. R-squared:                  0.745
# Method:                 Least Squares   F-statistic:                     1058.
# Date:                Thu, 31 Mar 2022   Prob (F-statistic):               0.00
# Time:                        22:24:35   Log-Likelihood:            -1.9595e+05
# No. Observations:               14469   AIC:                         3.920e+05
# Df Residuals:                   14428   BIC:                         3.923e+05
# Df Model:                          40
# Covariance Type:            nonrobust
# ===================================================================================================
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# Intercept                        2.744e+05   9290.223     29.532      0.000    2.56e+05    2.93e+05
# sqft_living                       179.7045      3.207     56.035      0.000     173.418     185.991
# bedrooms                        -1.523e+04   2113.146     -7.205      0.000   -1.94e+04   -1.11e+04
# renovated                        5.093e+04   1.75e+04      2.914      0.004    1.67e+04    8.52e+04
# house_age                         872.4309     70.225     12.423      0.000     734.781    1010.081
# grade_10verygood                 3.217e+05   9011.273     35.705      0.000    3.04e+05    3.39e+05
# grade_11excellent                5.533e+05   1.42e+04     39.019      0.000    5.25e+05    5.81e+05
# grade_12luxury                   1.005e+06   2.59e+04     38.749      0.000    9.54e+05    1.06e+06
# grade_13mansion                  1.938e+06   7.74e+04     25.035      0.000    1.79e+06    2.09e+06
# grade_3poor                      3.003e+05   1.85e+05      1.626      0.104   -6.17e+04    6.62e+05
# grade_4low                      -1.023e+04   4.16e+04     -0.246      0.806   -9.17e+04    7.13e+04
# grade_5fair                     -4.005e+04   1.54e+04     -2.593      0.010   -7.03e+04   -9772.114
# grade_6lowaverage               -3.323e+04   5991.008     -5.546      0.000    -4.5e+04   -2.15e+04
# grade_8good                      5.573e+04   4216.177     13.217      0.000    4.75e+04     6.4e+04
# grade_9better                    1.664e+05   6330.180     26.280      0.000    1.54e+05    1.79e+05
# waterfront_yes                   6.329e+05   2.26e+04     28.045      0.000    5.89e+05    6.77e+05
# view_average                     5.558e+04   7582.043      7.330      0.000    4.07e+04    7.04e+04
# view_excellent                   2.427e+05   1.54e+04     15.758      0.000    2.13e+05    2.73e+05
# view_fair                         1.02e+05   1.28e+04      7.964      0.000    7.69e+04    1.27e+05
# view_good                          1.2e+05   1.02e+04     11.721      0.000    9.99e+04     1.4e+05
# dist_seattle                    -1.439e+04    320.784    -44.855      0.000    -1.5e+04   -1.38e+04
# neighborhood_ballard             2.828e+04   1.06e+04      2.665      0.008    7480.729    4.91e+04
# neighborhood_beaconhill         -1.426e+05   1.41e+04    -10.111      0.000    -1.7e+05   -1.15e+05
# neighborhood_capitolhill         2.087e+05   1.46e+04     14.271      0.000     1.8e+05    2.37e+05
# neighborhood_cascade             6.427e+04   3.52e+04      1.823      0.068   -4823.870    1.33e+05
# neighborhood_centralarea         2.353e+04   1.12e+04      2.106      0.035    1630.931    4.54e+04
# neighborhood_delridge           -1.264e+05   1.08e+04    -11.715      0.000   -1.48e+05   -1.05e+05
# neighborhood_downtown           -4.442e+04   1.85e+05     -0.241      0.810   -4.06e+05    3.17e+05
# neighborhood_greaterduwamish    -1.924e+05   3.51e+04     -5.480      0.000   -2.61e+05   -1.24e+05
# neighborhood_interbay           -2.526e+04   9.24e+04     -0.273      0.785   -2.06e+05    1.56e+05
# neighborhood_lakecity           -4.478e+04   1.28e+04     -3.499      0.000   -6.99e+04   -1.97e+04
# neighborhood_magnolia            3.869e+04    1.4e+04      2.772      0.006    1.13e+04     6.6e+04
# neighborhood_northcentral        6.993e+04   1.05e+04      6.629      0.000    4.92e+04    9.06e+04
# neighborhood_northeast            9.59e+04   1.03e+04      9.333      0.000    7.58e+04    1.16e+05
# neighborhood_northgate          -5.279e+04   1.16e+04     -4.570      0.000   -7.54e+04   -3.01e+04
# neighborhood_northwest          -2.428e+04   1.01e+04     -2.405      0.016   -4.41e+04   -4495.249
# neighborhood_queenanne           1.346e+05   1.39e+04      9.673      0.000    1.07e+05    1.62e+05
# neighborhood_rainiervalley      -1.037e+05   1.03e+04    -10.073      0.000   -1.24e+05   -8.35e+04
# neighborhood_sewardpark         -2.847e+04   2.14e+04     -1.330      0.183   -7.04e+04    1.35e+04
# neighborhood_universitydistrict  2.577e+04   3.88e+04      0.665      0.506   -5.02e+04    1.02e+05
# neighborhood_westseattle        -4.397e+04   8712.614     -5.046      0.000    -6.1e+04   -2.69e+04
# ==============================================================================
# Omnibus:                     9648.138   Durbin-Watson:                   2.018
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           576982.052
# Skew:                           2.534   Prob(JB):                         0.00
# Kurtosis:                      33.518   Cond. No.                     2.74e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.74e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
display( make_vif(model_3_formula, train_df) )
# Out:
#                             feature        VIF
# 0                         Intercept  36.697797
# 1                       sqft_living   3.678246
# 2                          bedrooms   1.655383
# 3                         renovated   1.015081
# 4                         house_age   1.823455
# 5                  grade_10verygood   1.767345
# 6                 grade_11excellent   1.565483
# 7                    grade_12luxury   1.238760
# 8                   grade_13mansion   1.055846
# 9                       grade_3poor   1.002349
# 10                       grade_4low   1.015043
# 11                      grade_5fair   1.068062
# 12                grade_6lowaverage   1.317581
# 13                      grade_8good   1.534635
# 14                    grade_9better   1.827524
# 15                   waterfront_yes   1.397841
# 16                     view_average   1.061046
# 17                   view_excellent   1.443097
# 18                        view_fair   1.034253
# 19                        view_good   1.066054
# 20                     dist_seattle   2.142675
# 21             neighborhood_ballard   1.155678
# 22          neighborhood_beaconhill   1.072737
# 23         neighborhood_capitolhill   1.123465
# 24             neighborhood_cascade   1.020356
# 25         neighborhood_centralarea   1.175412
# 26            neighborhood_delridge   1.135166
# 27            neighborhood_downtown   1.001256
# 28     neighborhood_greaterduwamish   1.012148
# 29            neighborhood_interbay   1.002866
# 30            neighborhood_lakecity   1.056613
# 31            neighborhood_magnolia   1.101069
# 32        neighborhood_northcentral   1.194552
# 33           neighborhood_northeast   1.153780
# 34           neighborhood_northgate   1.091566
# 35           neighborhood_northwest   1.127955
# 36           neighborhood_queenanne   1.139513
# 37       neighborhood_rainiervalley   1.120411
# 38          neighborhood_sewardpark   1.031149
# 39  neighborhood_universitydistrict   1.014539
# 40         neighborhood_westseattle   1.235800

# %%
model_4_formula = 'price ~ ' + ' + '.join(model_4_cols)

# %%
model_4_mod = ols(model_4_formula, train_df).fit()
model_4_mod_summary = model_4_mod.summary()
model_4_mod_summary
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.834
# Model:                            OLS   Adj. R-squared:                  0.833
# Method:                 Least Squares   F-statistic:                     661.2
# Date:                Thu, 31 Mar 2022   Prob (F-statistic):               0.00
# Time:                        22:24:37   Log-Likelihood:            -1.9287e+05
# No. Observations:               14469   AIC:                         3.860e+05
# Df Residuals:                   14359   BIC:                         3.868e+05
# Df Model:                         109
# Covariance Type:            nonrobust
# ===================================================================================================
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# Intercept                        1.342e+05   2.37e+04      5.652      0.000    8.77e+04    1.81e+05
# sqft_living                       163.0242      2.643     61.673      0.000     157.843     168.206
# bedrooms                        -9910.0557   1731.548     -5.723      0.000   -1.33e+04   -6515.998
# renovated                        6.232e+04   1.42e+04      4.391      0.000    3.45e+04    9.01e+04
# house_age                         553.4883     59.111      9.363      0.000     437.622     669.354
# grade_10verygood                 2.455e+05   7573.055     32.424      0.000    2.31e+05     2.6e+05
# grade_11excellent                4.365e+05   1.17e+04     37.235      0.000    4.14e+05     4.6e+05
# grade_12luxury                   8.317e+05   2.13e+04     39.014      0.000     7.9e+05    8.73e+05
# grade_13mansion                  1.798e+06   6.31e+04     28.498      0.000    1.67e+06    1.92e+06
# grade_3poor                      1.508e+05    1.5e+05      1.005      0.315   -1.43e+05    4.45e+05
# grade_4low                       2.027e+04   3.38e+04      0.599      0.549   -4.61e+04    8.66e+04
# grade_5fair                     -1.103e+04   1.27e+04     -0.871      0.384   -3.59e+04    1.38e+04
# grade_6lowaverage               -8041.4836   4960.827     -1.621      0.105   -1.78e+04    1682.379
# grade_8good                      2.876e+04   3518.810      8.172      0.000    2.19e+04    3.57e+04
# grade_9better                    1.129e+05   5294.371     21.322      0.000    1.03e+05    1.23e+05
# waterfront_yes                   6.434e+05   1.86e+04     34.556      0.000    6.07e+05     6.8e+05
# view_average                     6.735e+04   6249.899     10.776      0.000    5.51e+04    7.96e+04
# view_excellent                   2.828e+05   1.27e+04     22.353      0.000    2.58e+05    3.08e+05
# view_fair                        6.953e+04   1.05e+04      6.637      0.000     4.9e+04    9.01e+04
# view_good                        1.451e+05   8427.529     17.214      0.000    1.29e+05    1.62e+05
# dist_seattle                    -7934.8539    956.396     -8.297      0.000   -9809.514   -6060.193
# neighborhood_ballard             5.915e+04   2.02e+04      2.933      0.003    1.96e+04    9.87e+04
# neighborhood_beaconhill         -5.254e+04   2.78e+04     -1.887      0.059   -1.07e+05    2036.062
# neighborhood_capitolhill         5374.0180   3.66e+04      0.147      0.883   -6.63e+04    7.71e+04
# neighborhood_cascade            -1.397e+04   5.15e+04     -0.271      0.786   -1.15e+05     8.7e+04
# neighborhood_centralarea        -2.542e+04   3.05e+04     -0.835      0.404   -8.51e+04    3.43e+04
# neighborhood_delridge            1.228e+04   2.44e+04      0.503      0.615   -3.55e+04    6.01e+04
# neighborhood_downtown           -7.585e+04   1.53e+05     -0.496      0.620   -3.76e+05    2.24e+05
# neighborhood_greaterduwamish     -8.72e+04   4.14e+04     -2.104      0.035   -1.68e+05   -5967.952
# neighborhood_interbay           -3972.9218   1.91e+05     -0.021      0.983   -3.78e+05     3.7e+05
# neighborhood_lakecity            3.188e+04   2.37e+04      1.346      0.178   -1.45e+04    7.83e+04
# neighborhood_magnolia            8.456e+04   1.76e+05      0.480      0.631   -2.61e+05     4.3e+05
# neighborhood_northcentral        1.156e+05   1.82e+04      6.366      0.000       8e+04    1.51e+05
# neighborhood_northeast           1.256e+05   2.14e+04      5.872      0.000    8.37e+04    1.68e+05
# neighborhood_northgate           1.131e+04   1.62e+04      0.697      0.486   -2.05e+04    4.31e+04
# neighborhood_northwest           2.138e+04   1.47e+04      1.457      0.145   -7380.797    5.01e+04
# neighborhood_queenanne           1.521e+05   9.25e+04      1.645      0.100   -2.92e+04    3.33e+05
# neighborhood_rainiervalley       2.269e+04    2.3e+04      0.986      0.324   -2.24e+04    6.78e+04
# neighborhood_sewardpark          1.373e+05      3e+04      4.571      0.000    7.84e+04    1.96e+05
# neighborhood_universitydistrict -4.119e+04    3.9e+04     -1.056      0.291   -1.18e+05    3.53e+04
# neighborhood_westseattle         5.632e+04   2.18e+04      2.578      0.010    1.35e+04    9.91e+04
# zip_98002                        2.076e+04   1.62e+04      1.282      0.200    -1.1e+04    5.25e+04
# zip_98003                       -1.536e+04   1.48e+04     -1.039      0.299   -4.43e+04    1.36e+04
# zip_98004                        6.391e+05   2.01e+04     31.776      0.000       6e+05    6.79e+05
# zip_98005                        2.165e+05    2.1e+04     10.300      0.000    1.75e+05    2.58e+05
# zip_98006                        1.731e+05   1.68e+04     10.278      0.000     1.4e+05    2.06e+05
# zip_98007                        1.593e+05   2.18e+04      7.319      0.000    1.17e+05    2.02e+05
# zip_98008                        1.873e+05   1.82e+04     10.276      0.000    1.52e+05    2.23e+05
# zip_98010                        1.033e+05    2.2e+04      4.695      0.000    6.02e+04    1.46e+05
# zip_98011                        6.233e+04   1.89e+04      3.304      0.001    2.54e+04    9.93e+04
# zip_98014                        1.322e+05   1.91e+04      6.920      0.000    9.47e+04     1.7e+05
# zip_98019                        9.418e+04   1.69e+04      5.588      0.000    6.11e+04    1.27e+05
# zip_98022                        1.108e+05   1.89e+04      5.871      0.000    7.38e+04    1.48e+05
# zip_98023                       -2.487e+04   1.29e+04     -1.926      0.054   -5.02e+04     440.179
# zip_98024                        1.791e+05   2.17e+04      8.264      0.000    1.37e+05    2.22e+05
# zip_98027                        1.226e+05   1.45e+04      8.441      0.000    9.42e+04    1.51e+05
# zip_98028                        3.567e+04   1.81e+04      1.973      0.048     235.638    7.11e+04
# zip_98029                        1.844e+05   1.51e+04     12.217      0.000    1.55e+05    2.14e+05
# zip_98030                       -1.396e+04    1.5e+04     -0.928      0.353   -4.34e+04    1.55e+04
# zip_98031                       -1.931e+04   1.54e+04     -1.258      0.208   -4.94e+04    1.08e+04
# zip_98032                       -4.681e+04   2.01e+04     -2.329      0.020   -8.62e+04   -7409.552
# zip_98033                        2.575e+05    1.8e+04     14.327      0.000    2.22e+05    2.93e+05
# zip_98034                        1.094e+05   1.69e+04      6.455      0.000    7.61e+04    1.43e+05
# zip_98038                        5.124e+04   1.25e+04      4.104      0.000    2.68e+04    7.57e+04
# zip_98039                        1.214e+06   3.21e+04     37.761      0.000    1.15e+06    1.28e+06
# zip_98040                        4.133e+05   2.01e+04     20.586      0.000    3.74e+05    4.53e+05
# zip_98042                        1.112e+04   1.28e+04      0.871      0.384   -1.39e+04    3.62e+04
# zip_98045                        1.568e+05   1.74e+04      9.014      0.000    1.23e+05    1.91e+05
# zip_98052                        1.679e+05   1.55e+04     10.822      0.000    1.38e+05    1.98e+05
# zip_98053                        1.766e+05   1.45e+04     12.197      0.000    1.48e+05    2.05e+05
# zip_98055                       -2.305e+04   1.68e+04     -1.373      0.170    -5.6e+04    9864.190
# zip_98056                        1.761e+04   1.69e+04      1.042      0.297   -1.55e+04    5.07e+04
# zip_98058                       -1.224e+04   1.44e+04     -0.848      0.396   -4.05e+04     1.6e+04
# zip_98059                        3.067e+04   1.52e+04      2.015      0.044     837.881    6.05e+04
# zip_98065                        1.145e+05   1.47e+04      7.810      0.000    8.57e+04    1.43e+05
# zip_98070                       -2.486e+04   2.09e+04     -1.188      0.235   -6.59e+04    1.62e+04
# zip_98072                        1.099e+05   1.66e+04      6.618      0.000    7.74e+04    1.42e+05
# zip_98074                        1.134e+05   1.49e+04      7.592      0.000    8.41e+04    1.43e+05
# zip_98075                         1.36e+05   1.52e+04      8.958      0.000    1.06e+05    1.66e+05
# zip_98077                        8.796e+04   1.71e+04      5.134      0.000    5.44e+04    1.22e+05
# zip_98092                       -4783.8271   1.38e+04     -0.347      0.728   -3.18e+04    2.22e+04
# zip_98102                        2.623e+05   4.59e+04      5.714      0.000    1.72e+05    3.52e+05
# zip_98103                        1.035e+05   2.35e+04      4.399      0.000    5.74e+04     1.5e+05
# zip_98105                        2.238e+05   2.84e+04      7.880      0.000    1.68e+05    2.79e+05
# zip_98106                       -2.791e+04   3.05e+04     -0.914      0.361   -8.78e+04     3.2e+04
# zip_98107                        1.234e+05   2.73e+04      4.527      0.000       7e+04    1.77e+05
# zip_98108                        2.289e+04   3.52e+04      0.650      0.516   -4.61e+04    9.19e+04
# zip_98109                         1.95e+05   9.31e+04      2.094      0.036    1.25e+04    3.77e+05
# zip_98112                        4.746e+05   4.06e+04     11.702      0.000    3.95e+05    5.54e+05
# zip_98115                        9.897e+04   2.57e+04      3.848      0.000    4.86e+04    1.49e+05
# zip_98116                        8.126e+04   3.07e+04      2.644      0.008     2.1e+04    1.41e+05
# zip_98117                        1.205e+05    2.4e+04      5.011      0.000    7.34e+04    1.68e+05
# zip_98118                       -1.277e+04   2.99e+04     -0.427      0.669   -7.14e+04    4.59e+04
# zip_98119                        1.676e+05   9.56e+04      1.754      0.079   -1.97e+04    3.55e+05
# zip_98122                         2.06e+05   3.78e+04      5.454      0.000    1.32e+05     2.8e+05
# zip_98125                        4.708e+04    2.7e+04      1.742      0.081   -5885.641       1e+05
# zip_98126                        1.446e+04   2.93e+04      0.494      0.621   -4.29e+04    7.18e+04
# zip_98133                        4.005e+04   1.87e+04      2.146      0.032    3470.650    7.66e+04
# zip_98136                        5.519e+04   2.99e+04      1.843      0.065   -3495.715    1.14e+05
# zip_98144                        1.355e+05   3.32e+04      4.079      0.000    7.04e+04    2.01e+05
# zip_98146                       -3.513e+04   2.03e+04     -1.733      0.083   -7.49e+04    4608.909
# zip_98148                        4268.9951   2.76e+04      0.155      0.877   -4.98e+04    5.83e+04
# zip_98155                         4.68e+04   1.74e+04      2.696      0.007    1.28e+04    8.08e+04
# zip_98166                       -1.588e+04   1.81e+04     -0.877      0.380   -5.14e+04    1.96e+04
# zip_98168                       -6.791e+04   1.93e+04     -3.527      0.000   -1.06e+05   -3.02e+04
# zip_98177                        9.963e+04   2.03e+04      4.908      0.000    5.98e+04    1.39e+05
# zip_98178                       -8.286e+04   2.02e+04     -4.106      0.000   -1.22e+05   -4.33e+04
# zip_98188                       -4.385e+04   2.13e+04     -2.059      0.039   -8.56e+04   -2110.788
# zip_98198                       -4.635e+04   1.58e+04     -2.927      0.003   -7.74e+04   -1.53e+04
# zip_98199                        1.407e+05   1.77e+05      0.796      0.426   -2.06e+05    4.87e+05
# ==============================================================================
# Omnibus:                    10771.837   Durbin-Watson:                   2.003
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1223182.940
# Skew:                           2.808   Prob(JB):                         0.00
# Kurtosis:                      47.692   Cond. No.                     5.92e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.92e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
display( make_vif(model_4_formula, train_df) )
# Out:
#          feature         VIF
# 0      Intercept  365.190417
# 1    sqft_living    3.805948
# 2       bedrooms    1.692846
# 3      renovated    1.019692
# 4      house_age    1.967726
# ..           ...         ...
# 105    zip_98177    3.008296
# 106    zip_98178    3.169129
# 107    zip_98188    1.634845
# 108    zip_98198    2.006647
# 109    zip_98199  276.025317
#
# [110 rows x 2 columns]

# %% [markdown]
# ## Visualization

# %%
filt = (train_df['bedrooms'].isin([2,3,4])) & (train_df['price'] <= 2000000) & (train_df['sqft_living'] <=4000)
cleaner_train_df = train_df[filt]
cleaner_train_df['price'] = cleaner_train_df['price'] / 1000
#fig, ax = plt.subplots(1)
sns.lmplot(y='price', x='sqft_living', hue='bedrooms', data=cleaner_train_df, scatter=False)
#ax.ticklabel_format(style='plain', axis='y');   #scilimits=(6,6));

plt.savefig('../Images/lmplot_price-vs-sqft_living-by_bedrooms.jpg', transparent = False, bbox_inches="tight");

# %%
# Probably could have done this differently, but just needed a way to order and plot the levels of grade
cleaner_train_df['grade_ordinal'] = (cleaner_train_df['grade_3poor'] * 3) + (cleaner_train_df['grade_4low'] * 4) + \
(cleaner_train_df['grade_5fair'] * 5) + (cleaner_train_df['grade_6lowaverage'] * 6) + \
(cleaner_train_df['grade_7average'] * 7) + (cleaner_train_df['grade_8good'] * 8) + \
(cleaner_train_df['grade_9better'] * 9) + (cleaner_train_df['grade_10verygood'] * 10) + \
(cleaner_train_df['grade_11excellent'] * 11) + (cleaner_train_df['grade_12luxury'] * 12) + \
(cleaner_train_df['grade_13mansion'] * 13)

# %%
cleaner_train_df['grade_ordinal'].describe()
# Out:
# count    12668.000000
# mean         7.548784
# std          1.038641
# min          4.000000
# 25%          7.000000
# 50%          7.000000
# 75%          8.000000
# max         12.000000
# Name: grade_ordinal, dtype: float64

# %%
filt = (cleaner_train_df['grade_ordinal'] >= 6) & (cleaner_train_df['grade_ordinal'] <= 10)

sns.catplot(x="grade_ordinal", y="price", hue="renovated", kind="bar", data=cleaner_train_df[filt])
plt.savefig('../Images/barplot_price-vs-grade-by-renovated.jpg', transparent = False, bbox_inches="tight");

# %%
list1 = ['1', '2', '3']
list2 = ['4', '5', '6']
list3 = list1 + list2
print(list1)
print(list2)
print(list3)
# Out:
# ['1', '2', '3']
# ['4', '5', '6']
# ['1', '2', '3', '4', '5', '6']

# %%
model_base_cols = ['sqft_living', 'bedrooms']
model_1_cols = model_base_cols + \
    ['renovated', 'house_age', 'grade_10verygood', 'grade_11excellent', 'grade_12luxury', 'grade_13mansion', 
     'grade_3poor', 'grade_4low', 'grade_5fair', 'grade_6lowaverage', 'grade_8good', 'grade_9better']

print(model_1_cols)
# Out:
# ['sqft_living', 'bedrooms', 'renovated', 'house_age', 'grade_10verygood', 'grade_11excellent', 'grade_12luxury', 'grade_13mansion', 'grade_3poor', 'grade_4low', 'grade_5fair', 'grade_6lowaverage', 'grade_8good', 'grade_9better']

# %%
X_formula = 'price ~ ' + ' + '.join(model_2_cols)

# %%
X_formula
# Out:
# 'price ~ sqft_living + bedrooms + renovated + house_age + grade_10verygood + grade_11excellent + grade_12luxury + grade_13mansion + grade_3poor + grade_4low + grade_5fair + grade_6lowaverage + grade_8good + grade_9better + waterfront_yes + view_average + view_excellent + view_fair + view_good'
